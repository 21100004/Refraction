# %%
import refraction

# %%
interLen = 10
refIndex1 = 1
refIndex2 = 1.33
fig = refraction.makeInterface(interLen, refIndex1, refIndex2)

# %%
interLen = 10
numPiece = 10
refIndex1 = 1
refIndex2 = 1.33
fig = refraction.divideInterface(interLen, numPiece, refIndex1, refIndex2)

# %%
interLen = 10
numPiece = 10
refIndex1 = 1
refIndex2 = 1.33
sourceX = 0
sourceY = 10
photoX = 10
photoY = -10
fig = refraction.placeSAndP(interLen, numPiece, refIndex1, refIndex2, sourceX, sourceY, photoX, photoY)

# %%
interLen = 10
refIndex1 = 1
refIndex2 = 2
sourceX = 0
sourceY = 10
photoX = 10
photoY = -10
fig = refraction.classicalPath(interLen, numPiece, refIndex1, refIndex2, sourceX, sourceY, photoX, photoY)

# %%
interLen = 10
numPiece = 10
refIndex1 = 1
refIndex2 = 2
sourceX = 0
sourceY = 10
photoX = 10
photoY = -10
refraction.QEDPath(interLen, numPiece, refIndex1, refIndex2, sourceX, sourceY, photoX, photoY)

# %%
interLen = 10
numPiece = 10
refIndex1 = 1
refIndex2 = 2
sourceX = 0
sourceY = 10
photoX = 10
photoY = -10
speed = 3*10**8
times = refraction.createTimes(interLen, numPiece, refIndex1, refIndex2, sourceX, sourceY, photoX, photoY, speed)
refraction.plotTimes(interLen, numPiece, times)

# %%
interLen = 10
numPiece = 1500
refIndex1 = 1
refIndex2 = 2
sourceX = 0
sourceY = 10
photoX = 10
photoY = -10
speed = 3*10**8
startInd = 0
endInd = 1499
times = refraction.createTimes(interLen, numPiece, refIndex1, refIndex2, sourceX, sourceY, photoX, photoY, speed)
reals, imags, z = refraction.phasorsOnInterface(interLen, numPiece, times)
refraction.addPhasors(numPiece, reals, imags, z, startInd, endInd)
